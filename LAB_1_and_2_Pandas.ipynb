# %% [markdown]
# <a href="https://colab.research.google.com/github/Alokkr00/Alokkr00/blob/main/LAB_1_and_2_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/cafe.csv")

# %%
data.head()
# Out:
#    Store ID                              Name   Brand Ownership Type  \
# 0     92040                              Fort  Railey         JointV
# 1     92351       Goregaon East - Oberoi Mall  Railey         JointV
# 2     92413                            Colaba  Railey         JointV
# 3    113991                             Powai  Railey         JointV
# 4    114012  Indira Gandhi Itnl Arpt-T3Gate15  Railey         JointV
#
#                                              Address       City State Country  \
# 0  Elphinstone Building, Horniman Circle, Veer Na...     Mumbai    MH      IN
# 1       Off Western Express Highway, Goregaon (East)     Mumbai    MH      IN
# 2  Hotel Taj Mahal Palace, Apollo Bunder, Apollo ...     Mumbai    MH      IN
# 3  Prudential Bldg Hiranandani Bus Park, Gr Fl, C...     Mumbai    MH      IN
# 4  International Departure, Near Gate 15, Terminal 3  New Delhi    DL      IN
#
#   Postal Code   Latitude  Longitude      Launch Date  AFF-Mon  AFF-Tue  \
# ...

# %%
data["AFF-Mon"].sum()
# Out:
# 26966

# %%
data["AFF-Mon"].min()
# Out:
# 122

# %%
data["AFF-Mon"].describe()
# Out:
# count     85.000000
# mean     317.247059
# std       49.312151
# min      122.000000
# 25%      287.000000
# 50%      314.000000
# 75%      353.000000
# max      399.000000
# Name: AFF-Mon, dtype: float64

# %%
data.describe()
# Out:
#            Store ID   Latitude  Longitude     AFF-Mon     AFF-Tue    AFF-Wed  \
# count  8.500000e+01  85.000000  85.000000   85.000000   85.000000   85.00000
# mean   8.711734e+05  20.652921  75.529383  317.247059  147.552941  336.80000
# std    3.254030e+05   5.567772   2.478295   49.312151   29.774352   56.27564
# min    9.204000e+04  12.906010  72.811928  122.000000  100.000000   78.00000
# 25%    1.006014e+06  18.519234  72.860535  287.000000  126.000000  303.00000
# 50%    1.006943e+06  19.086382  77.072586  314.000000  143.000000  348.00000
# 75%    1.009882e+06  28.475670  77.251785  353.000000  172.000000  377.00000
# max    1.015306e+06  28.693115  80.264076  399.000000  198.000000  397.00000
#
#           AFF-Thu     AFF-Fri     AFF-Sat     AFF-Sun
# count   85.000000   85.000000   85.000000   85.000000
# mean   359.129412  495.070588  549.317647  397.176471
# std     58.631575   35.595207   32.255015   36.494676
# min    191.000000  352.000000  441.000000  206.000000
# ...

# %%
data.describe(include="all")
# Out:
#             Store ID  Name   Brand Ownership Type  \
# count   8.500000e+01    85      85             85
# unique           NaN    85       1              1
# top              NaN  Fort  Railey         JointV
# freq             NaN     1      85             85
# mean    8.711734e+05   NaN     NaN            NaN
# std     3.254030e+05   NaN     NaN            NaN
# min     9.204000e+04   NaN     NaN            NaN
# 25%     1.006014e+06   NaN     NaN            NaN
# 50%     1.006943e+06   NaN     NaN            NaN
# 75%     1.009882e+06   NaN     NaN            NaN
# max     1.015306e+06   NaN     NaN            NaN
#
#                                                   Address    City State  \
# count                                                  85      85    85
# unique                                                 85      10     7
# top     Elphinstone Building, Horniman Circle, Veer Na...  Mumbai    MH
# ...

# %%
data.tail()
# Out:
#     Store ID                                 Name   Brand Ownership Type  \
# 80   1013682                            Sector 16  Railey         JointV
# 81   1008832  Chhatrapati Shivaji International A  Railey         JointV
# 82   1006943                    Greater Kailash 2  Railey         JointV
# 83   1013443                Bandra East - One BKC  Railey         JointV
# 84   1015306                   One Horizon Center  Railey         JointV
#
#                                               Address       City State  \
# 80          Ground Floor, Gardens Galleria, Sector 16      Noida    UP
# 81  T2 Departure SHA, Level P9, Food Court, Andher...     Mumbai    MH
# 82  Ground Floor, M-11, M-Block, Main Mrkt, Greate...  New Delhi    DL
# 83  A wing, Ground Floor, One BKC, G Block,BandraB...     Mumbai    MH
# 84                                   Golf Course Road    Gurgaon    HR
#
#    Country Postal Code   Latitude  Longitude     Launch Date  AFF-Mon  \
# ...

# %%
data.columns
# Out:
# Index(['Store ID', 'Name', 'Brand', 'Ownership Type', 'Address', 'City',
#        'State', 'Country', 'Postal Code', 'Latitude', 'Longitude',
#        'Launch Date', 'AFF-Mon', 'AFF-Tue', 'AFF-Wed', 'AFF-Thu', 'AFF-Fri',
#        'AFF-Sat', 'AFF-Sun'],
#       dtype='object')

# %%
data["State"].unique()
# Out:
# array(['MH', 'DL', 'HR', 'KA', 'TN', 'AP', 'UP'], dtype=object)

# %%
data["State"].unique()
# Out:
# array(['MH', 'DL', 'HR', 'KA', 'TN', 'AP', 'UP'], dtype=object)

# %%
data["State"].nunique()
# Out:
# 7

# %%
data.shape
# Out:
# (85, 19)

# %%
x=[i for i in range(85)]

# %%
data["New Index"]=x

# %%
data.columns
# Out:
# Index(['Store ID', 'Name', 'Brand', 'Ownership Type', 'Address', 'City',
#        'State', 'Country', 'Postal Code', 'Latitude', 'Longitude',
#        'Launch Date', 'AFF-Mon', 'AFF-Tue', 'AFF-Wed', 'AFF-Thu', 'AFF-Fri',
#        'AFF-Sat', 'AFF-Sun', 'New Index'],
#       dtype='object')

# %%
data.shape
# Out:
# (85, 20)

# %%
data.head()
# Out:
#    Store ID                              Name   Brand Ownership Type  \
# 0     92040                              Fort  Railey         JointV
# 1     92351       Goregaon East - Oberoi Mall  Railey         JointV
# 2     92413                            Colaba  Railey         JointV
# 3    113991                             Powai  Railey         JointV
# 4    114012  Indira Gandhi Itnl Arpt-T3Gate15  Railey         JointV
#
#                                              Address       City State Country  \
# 0  Elphinstone Building, Horniman Circle, Veer Na...     Mumbai    MH      IN
# 1       Off Western Express Highway, Goregaon (East)     Mumbai    MH      IN
# 2  Hotel Taj Mahal Palace, Apollo Bunder, Apollo ...     Mumbai    MH      IN
# 3  Prudential Bldg Hiranandani Bus Park, Gr Fl, C...     Mumbai    MH      IN
# 4  International Departure, Near Gate 15, Terminal 3  New Delhi    DL      IN
#
#   Postal Code   Latitude  Longitude      Launch Date  AFF-Mon  AFF-Tue  \
# ...

# %%
data.drop("New Index",axis=1,inplace=True) # axis=1 for columns and axis=0 for rows

# %%
data[data["State"]=="TN"]
# Out:
#     Store ID          Name   Brand Ownership Type  \
# 46   1007196     Velachery  Railey         JointV
# 62   1011564    Anna Nagar  Railey         JointV
# 67   1011563    Royapettah  Railey         JointV
# 73   1012363  Numgambakkam  Railey         JointV
# 74   1013162      Alwarpet  Railey         JointV
#
#                                               Address     City State Country  \
# 46  Upper Ground Floor, Phoenix marketcity, Velach...  Chennai    TN      IN
# 62  TBR tower, Y block, 2nd Avenue, Near Ayyappa T...  Chennai    TN      IN
# 67  Ground Floor, Express Avenue Mall, Whites Road...  Chennai    TN      IN
# 73  Ground Floor, Bergamo Mall, Khadar Nawas Khan ...  Chennai    TN      IN
# 74  Ground Floor, MGN Splendor, Off Chamiers Road,...  Chennai    TN      IN
#
#    Postal Code   Latitude  Longitude     Launch Date  AFF-Mon  AFF-Tue  \
# 46      600042  12.991694  80.217026  7/17/2014 4:00      341      122
# ...

# %%
data.isna()
# Out:
#     Store ID   Name  Brand  Ownership Type  Address   City  State  Country  \
# 0      False  False  False           False    False  False  False    False
# 1      False  False  False           False    False  False  False    False
# 2      False  False  False           False    False  False  False    False
# 3      False  False  False           False    False  False  False    False
# 4      False  False  False           False    False  False  False    False
# ..       ...    ...    ...             ...      ...    ...    ...      ...
# 80     False  False  False           False    False  False  False    False
# 81     False  False  False           False    False  False  False    False
# 82     False  False  False           False    False  False  False    False
# 83     False  False  False           False    False  False  False    False
# 84     False  False  False           False    False  False  False    False
#
# ...

# %%
data['Store ID'].isna()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 80    False
# 81    False
# 82    False
# 83    False
# 84    False
# Name: Store ID, Length: 85, dtype: bool

# %%
data.isna().sum()
# Out:
# Store ID          0
# Name              0
# Brand             0
# Ownership Type    0
# Address           0
# City              0
# State             0
# Country           0
# Postal Code       0
# Latitude          0
# Longitude         0
# Launch Date       0
# AFF-Mon           0
# AFF-Tue           0
# AFF-Wed           0
# AFF-Thu           0
# AFF-Fri           0
# AFF-Sat           0
# AFF-Sun           0
# dtype: int64

# %%
data.isna().sum().sum()
# Out:
# 0

# %%
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/train.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df["Age"]=df["Age"].fillna(df["Age"].mean())

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %%
df.describe(include='all').T
# Out:
#              count unique                      top freq       mean  \
# PassengerId  891.0    NaN                      NaN  NaN      446.0
# Survived     891.0    NaN                      NaN  NaN   0.383838
# Pclass       891.0    NaN                      NaN  NaN   2.308642
# Name           891    891  Braund, Mr. Owen Harris    1        NaN
# Sex            891      2                     male  577        NaN
# Age          891.0    NaN                      NaN  NaN  29.699118
# SibSp        891.0    NaN                      NaN  NaN   0.523008
# Parch        891.0    NaN                      NaN  NaN   0.381594
# Ticket         891    681                   347082    7        NaN
# Fare         891.0    NaN                      NaN  NaN  32.204208
# Cabin          204    147                  B96 B98    4        NaN
# Embarked       889      3                        S  644        NaN
#
#                     std   min     25%        50%    75%       max
# ...

# %%
df.sample(n=4) # Random selection
# Out:
#      PassengerId  Survived  Pclass  \
# 216          217         1       3
# 862          863         1       1
# 572          573         1       1
# 688          689         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 216                             Honkanen, Miss. Eliina  female  27.0      0
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0      0
# 572                   Flynn, Mr. John Irwin ("Irving")    male  36.0      0
# 688                    Fischer, Mr. Eberhard Thelander    male  18.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 216      0  STON/O2. 3101283   7.9250   NaN        S
# 862      0             17466  25.9292   D17        S
# 572      0          PC 17474  26.3875   E25        S
# 688      0            350036   7.7958   NaN        S

# %%
#How to Get the unique value from every column ????

# %%
df.shape
# Out:
# (891, 12)

# %%
df.memory_usage() # how much memory used by each column
# Out:
# Index           128
# PassengerId    7128
# Survived       7128
# Pclass         7128
# Name           7128
# Sex            7128
# Age            7128
# SibSp          7128
# Parch          7128
# Ticket         7128
# Fare           7128
# Cabin          7128
# Embarked       7128
# dtype: int64

# %%
df.nsmallest(5,'Age')
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 803          804         1       3  Thomas, Master. Assad Alexander    male
# 755          756         1       2        Hamalainen, Master. Viljo    male
# 469          470         1       3    Baclini, Miss. Helene Barbara  female
# 644          645         1       3           Baclini, Miss. Eugenie  female
# 78            79         1       2    Caldwell, Master. Alden Gates    male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 803  0.42      0      1    2625   8.5167   NaN        C
# 755  0.67      1      1  250649  14.5000   NaN        S
# 469  0.75      2      1    2666  19.2583   NaN        C
# 644  0.75      2      1    2666  19.2583   NaN        C
# 78   0.83      0      2  248738  29.0000   NaN        S

# %%
df.nlargest(5,'Age')
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
# 96            97         0       1             Goldschmidt, Mr. George B
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 116          117         0       3                  Connors, Mr. Patrick
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 630  male  80.0      0      0     27042  30.0000   A23        S
# 851  male  74.0      0      0    347060   7.7750   NaN        S
# 96   male  71.0      0      0  PC 17754  34.6542    A5        C
# 493  male  71.0      0      0  PC 17609  49.5042   NaN        C
# 116  male  70.5      0      0    370369   7.7500   NaN        Q

# %%
df.loc[:5,['Age','Name']] #selection of specific colum and row
# Out:
#          Age                                               Name
# 0  22.000000                            Braund, Mr. Owen Harris
# 1  38.000000  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2  26.000000                             Heikkinen, Miss. Laina
# 3  35.000000       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4  35.000000                           Allen, Mr. William Henry
# 5  29.699118                                   Moran, Mr. James

# %%
df.iloc[:4,:4] #selection of specific rang of row and colum
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name
# 0                            Braund, Mr. Owen Harris
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                             Heikkinen, Miss. Laina
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)

# %%
df.iloc[2:4,1:4]   # from specific range select row and column
# Out:
#    Survived  Pclass                                          Name
# 2         1       3                        Heikkinen, Miss. Laina
# 3         1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)

# %%
df[0:4] #slicing
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %%
df[['Age','Fare']].groupby(['Age']).mean()
# Out:
#            Fare
# Age
# 0.42     8.5167
# 0.67    14.5000
# 0.75    19.2583
# 0.83    23.8750
# 0.92   151.5500
# ...         ...
# 70.00   40.7500
# 70.50    7.7500
# 71.00   42.0792
# 74.00    7.7750
# 80.00   30.0000
#
# [89 rows x 1 columns]

# %%
df.sort_index(axis=1,ascending=True)
# Out:
#            Age Cabin Embarked     Fare  \
# 0    22.000000   NaN        S   7.2500
# 1    38.000000   C85        C  71.2833
# 2    26.000000   NaN        S   7.9250
# 3    35.000000  C123        S  53.1000
# 4    35.000000   NaN        S   8.0500
# ..         ...   ...      ...      ...
# 886  27.000000   NaN        S  13.0000
# 887  19.000000   B42        S  30.0000
# 888  29.699118   NaN        S  23.4500
# 889  26.000000  C148        C  30.0000
# 890  32.000000   NaN        Q   7.7500
#
#                                                   Name  Parch  PassengerId  \
# 0                              Braund, Mr. Owen Harris      0            1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                               Heikkinen, Miss. Laina      0            3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                             Allen, Mr. William Henry      0            5
# ...

# %%
df[['Age','Fare']].groupby(['Age']).mean()
# Out:
#            Fare
# Age
# 0.42     8.5167
# 0.67    14.5000
# 0.75    19.2583
# 0.83    23.8750
# 0.92   151.5500
# ...         ...
# 70.00   40.7500
# 70.50    7.7500
# 71.00   42.0792
# 74.00    7.7750
# 80.00   30.0000
#
# [89 rows x 1 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df[['Sex','Pclass','PassengerId']].groupby(['Sex','Pclass']).count()
# Out:
#                PassengerId
# Sex    Pclass
# female 1                94
#        2                76
#        3               144
# male   1               122
#        2               108
#        3               347

# %%
df.sort_values(by='Fare')
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 271          272         1       3        Tornquist, Mr. William Henry
# 597          598         0       3                 Johnson, Mr. Alfred
# 302          303         0       3     Johnson, Mr. William Cahoone Jr
# 633          634         0       1       Parr, Mr. William Henry Marsh
# 277          278         0       2         Parkes, Mr. Francis "Frank"
# ..           ...       ...     ...                                 ...
# 438          439         0       1                   Fortune, Mr. Mark
# 341          342         1       1      Fortune, Miss. Alice Elizabeth
# 737          738         1       1              Lesurer, Mr. Gustave J
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
#
#         Sex        Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %%
data1=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/train.csv")

# %%
drop_cols=['Age']
data1.drop(drop_cols,axis=1,inplace=True)  #remove a row or a column from a dataframe which has NaN  or no value in it.

# %%
data1 # so there is no age column
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
data1.query('1<Pclass<3')[:8]  #specific Qurery based data collection
# Out:
#     PassengerId  Survived  Pclass  \
# 9            10         1       2
# 15           16         1       2
# 17           18         1       2
# 20           21         0       2
# 21           22         1       2
# 33           34         0       2
# 41           42         0       2
# 43           44         1       2
#
#                                                  Name     Sex  SibSp  Parch  \
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female      1      0
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female      0      0
# 17                       Williams, Mr. Charles Eugene    male      0      0
# 20                               Fynney, Mr. Joseph J    male      0      0
# 21                              Beesley, Mr. Lawrence    male      0      0
# 33                              Wheadon, Mr. Edward H    male      0      0
# 41  Turpin, Mrs. William John Robert (Dorothy Ann ...  female      1      0
# ...

# %%
data1.query('1<=Pclass<3')[:8]
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 9            10         1       2
# 11           12         1       1
# 15           16         1       2
# 17           18         1       2
# 20           21         0       2
#
#                                                  Name     Sex  SibSp  Parch  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 6                             McCarthy, Mr. Timothy J    male      0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female      1      0
# 11                           Bonnell, Miss. Elizabeth  female      0      0
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female      0      0
# 17                       Williams, Mr. Charles Eugene    male      0      0
# ...

# %%
# Q.1 Perform nsmallest() and nlargest() on column 'median_house_value'
#Q.2 Apply loc on 'median_income','median_house_value'
#Q.3 Select 4 rows and 6 column from data base
#Q.4 Perfom GroupBy on housing_median_age, median_house_value,total_rooms) according to (housing_median_age,medain_house_value)using mean() value
#Q.5 Sort the data using 'median_house_value'.
#Q.6 Drop column 'ocean_proximity'
#Q.7 select the 5 rows where median_house_value between 40000 to 100000

# %%
data_1=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/housing_dataset.csv')

# %%
data_1['median_house_value'].nsmallest()
# Out:
# 2521     14999
# 2799     14999
# 9188     14999
# 19802    14999
# 5887     17500
# Name: median_house_value, dtype: int64

# %%
data_1['median_house_value'].nlargest()
# Out:
# 89     500001
# 459    500001
# 493    500001
# 494    500001
# 509    500001
# Name: median_house_value, dtype: int64

# %%
data_1.loc[:5,['median_income','median_house_value']]
# Out:
#    median_income  median_house_value
# 0         8.3252              452600
# 1         8.3014              358500
# 2         7.2574              352100
# 3         5.6431              341300
# 4         3.8462              342200
# 5         4.0368              269700

# %%
data_1.iloc[:4,:6]
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
#
#    population
# 0         322
# 1        2401
# 2         496
# 3         558

# %%
data_1[['housing_median_age','median_house_value','total_rooms']].groupby(['housing_median_age']).mean()
# Out:
#                     median_house_value  total_rooms
# housing_median_age
# 1                        144300.000000  1101.250000
# 2                        224475.913793  5530.293103
# 3                        235643.580645  7160.080645
# 4                        229235.136126  6237.282723
# 5                        208417.655738  5018.307377
# 6                        203794.393750  4541.406250
# 7                        193296.034286  5430.720000
# 8                        194414.582524  3989.577670
# 9                        186672.702439  3831.624390
# 10                       176580.704545  3515.060606
# 11                       179907.901575  3876.736220
# 12                       182046.235294  4162.474790
# 13                       190181.807947  3630.771523
# 14                       189597.104369  3660.461165
# 15                       181808.416016  3282.472656
# 16                       200180.562905  2966.569390
# 17                       190494.289398  3159.464183
# ...

# %%
data_1[['housing_median_age','median_house_value','total_rooms']].groupby(['housing_median_age','median_house_value']).mean()
# Out:
#                                        total_rooms
# housing_median_age median_house_value
# 1                  55000                  6.000000
#                    141700                83.000000
#                    189200              2254.000000
#                    191300              2062.000000
# 2                  47500                 96.000000
# ...                                            ...
# 52                 494400              1345.000000
#                    494700              2425.000000
#                    498400              3034.000000
#                    500000              2058.300000
#                    500001              2281.964706
#
# [17532 rows x 1 columns]

# %%
data_1.sort_values(by='median_house_value')
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 9188     -117.86     34.24                  52          803           267.0
# 19802    -123.17     40.31                  36           98            28.0
# 2799     -117.02     36.40                  19          619           239.0
# 2521     -122.74     39.71                  16          255            73.0
# 5887     -118.33     34.15                  39          493           168.0
# ...          ...       ...                 ...          ...             ...
# 16938    -122.33     37.56                  50         1975           245.0
# 16936    -122.32     37.56                  49         2016           299.0
# 16935    -122.33     37.56                  34         6394          1619.0
# 8291     -118.15     33.76                  36         2916           785.0
# 18055    -121.99     37.25                  22         4240           532.0
#
# ...

# %%
data_1.drop("ocean_proximity",axis=1,inplace=True)

# %%
data_1.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
data_1.query('40000<median_house_value<100000')[:5]
# Out:
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 23    -122.27     37.84                  52         1688           337.0
# 26    -122.28     37.85                  49         1130           244.0
# 35    -122.27     37.83                  49         1215           282.0
# 51    -122.27     37.82                  43         1868           456.0
# 52    -122.27     37.82                  41         3221           853.0
#
#     population  households  median_income  median_house_value
# 23         853         325         2.1806               99700
# 26         607         239         2.4597               93800
# 35         570         264         1.4861               97200
# 51        1061         407         1.5045               93800
# 52        1959         720         1.1108               97500
